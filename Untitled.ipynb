# %%
from PIL import Image
import pytesseract
import torch

# %%
print(pytesseract.image_to_string('test4.png', lang='rus'))
# Out:
# <НАКА
#
# ПЕРЕВОДОВ:
#
# Перевод с английского и французского языка на русский язык
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Профессия
#
# Бухгалтер
#
# Адрес
#
# 77220 Турнанан-Бри
#
# Рост
#
# 170
#
# Особые приметы
#
# Смотреть фотографию
#
# Подпись уполномоченного лица
#
# "подписано
#
# ` Республика Кот-д'Ивуар.
#
# "Паспорт Тип Код страны "Паспорт №
#
# р сту
# ФОТОГРАФИЯ | Фамилия
# Имя
# МАРИАМ
# Национальность национальность Пол
# Жительнипа берега Слоновой кости жЖ
# `Дата рождения "Место рождения
# >;
#
# `Дата выдачи Орган выдачи
#
#
#
#
#
#
#
#
#
#
#
# и Управление воздушной и
# пограничной полиции
#
#
#
#
#
# `Дата окончания срока "Подпись владельца
# И ‘подписано
#
#
#
#
#
#
#
#
#
# ПЕЕМАВТАМе Е Еккекакекакккя
#
#
#
#
#
# НИ

# %%
print(pytesseract.image_to_boxes('test4.png', lang='rus'))
# Out:
# < 21 587 38 621 0
# Н 36 587 60 623 0
# А 62 587 81 618 0
# К 83 587 104 623 0
# А 102 587 142 631 0
# П 22 576 27 583 0
# Е 29 576 34 583 0
# Р 29 575 39 583 0
# Е 35 576 46 583 0
# В 47 576 52 583 0
# О 48 575 58 583 0
# Д 54 576 59 583 0
# О 60 575 73 583 0
# В 69 575 79 583 0
# : 74 576 79 583 0
# П 253 535 257 543 0
# е 256 538 266 551 0
# р 265 538 271 545 0
# е 271 535 283 551 0
# в 269 535 291 545 0
# о 285 535 297 551 0
# д 291 538 305 548 0
# с 310 538 316 545 0
# а 320 538 327 545 0
# н 323 538 335 548 0
# г 327 538 342 545 0
# л 335 538 347 548 0
# и 342 538 353 545 0
# й 349 538 361 548 0
# с 354 538 367 548 0
# к 361 538 373 548 0
# о 368 538 374 545 0
# г 375 538 381 545 0
# о 382 538 394 545 0
# и 399 538 406 545 0
# ф 410 535 420 549 0
# р 415 535 427 549 0
# а 418 535 434 545 0
# н 435 538 441 545 0
# ц 437 535 449 549 0
# у 442 535 454 545 0
# з 454 538 461 545 0
# с 455 535 467 549 0
# к 462 538 467 545 0
# о 468 538 475 545 0
# г 475 538 482 545 0
# ...

# %%
pytesseract.image_to_data('test4.png', lang='rus')
# Out:
# 'level\tpage_num\tblock_num\tpar_num\tline_num\tword_num\tleft\ttop\twidth\theight\tconf\ttext\n1\t1\t0\t0\t0\t0\t0\t0\t663\t645\t-1\t\n2\t1\t1\t0\t0\t0\t21\t14\t121\t44\t-1\t\n3\t1\t1\t1\t0\t0\t21\t14\t121\t44\t-1\t\n4\t1\t1\t1\t1\t0\t21\t14\t121\t44\t-1\t\n5\t1\t1\t1\t1\t1\t21\t14\t121\t44\t45\t<НАКА\n2\t1\t2\t0\t0\t0\t22\t62\t57\t8\t-1\t\n3\t1\t2\t1\t0\t0\t22\t62\t57\t8\t-1\t\n4\t1\t2\t1\t1\t0\t22\t62\t57\t8\t-1\t\n5\t1\t2\t1\t1\t1\t22\t62\t57\t8\t36\tПЕРЕВОДОВ:\n2\t1\t3\t0\t0\t0\t253\t94\t386\t16\t-1\t\n3\t1\t3\t1\t0\t0\t253\t94\t386\t16\t-1\t\n4\t1\t3\t1\t1\t0\t253\t94\t386\t16\t-1\t\n5\t1\t3\t1\t1\t1\t253\t94\t52\t16\t76\tПеревод\n5\t1\t3\t1\t1\t2\t310\t100\t6\t7\t96\tс\n5\t1\t3\t1\t1\t3\t320\t97\t74\t10\t94\tанглийского\n5\t1\t3\t1\t1\t4\t399\t100\t7\t7\t96\tи\n5\t1\t3\t1\t1\t5\t410\t96\t85\t14\t94\tфранцузского\n5\t1\t3\t1\t1\t6\t498\t100\t37\t7\t96\tязыка\n5\t1\t3\t1\t1\t7\t539\t100\t15\t7\t92\tна\n5\t1\t3\t1\t1\t8\t553\t90\t52\t24\t92\tрусский\n5\t1\t3\t1\t1\t9\t605\t90\t34
# ...
